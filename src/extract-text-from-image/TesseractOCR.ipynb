# %%
import pytesseract
from PIL import Image

# Đường dẫn đến tesseract executable nếu cần
# pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/tesseract'

# Nhận diện tiếng Anh và tiếng Việt (có thể thêm các ngôn ngữ khác nếu cần)
image_path = r'C:\Users\LENOVO\Desktop\chatKPT-2024-AIC-HCMC\data\batch1\keyframes\keyframes_L01\L01_V001\001.jpg'
text = pytesseract.image_to_string(Image.open(image_path), lang='eng+vie')

print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File c:\Users\LENOVO\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# ...
